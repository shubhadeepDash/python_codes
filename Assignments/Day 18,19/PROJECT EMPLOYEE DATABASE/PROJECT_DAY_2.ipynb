# %%
file = open("login.txt", "w")
l = ["admin\tadmin\n"]
file.writelines(l)
file.close()

# %%
def admin_module(): 
    def add_employee(emp_id, emp_name, emp_DOJ, emp_desig, emp_sal):
        file = open("Add_Emp.txt","a")
        L = ["Employee_ID:",emp_id,"\t\tEmployee_Name:",emp_name,"\t\tEmployee_DOJ:",emp_DOJ,"\t\tEmployee_Designation:",emp_desig,"\t\tEmployee_Salary:",emp_sal,"\n"]
        file.writelines(L)
        file.close()
        f = open("login.txt","a")
        q = emp_name.split()[0]
        LL = [emp_id,"\t",emp_name,"\n"]
        f.writelines(LL)
        f.close()
    
    def remove_emp(emp_id):
        fle = open("login.txt","r+")
        f = file.readlines()
        list1 = []
        flag = 0 
        for l in f:
            if emp_id not in l:
                list1.append(l)
            else:
                flag = 1
        if flag == 0:
            print("No such employee found.")
        fle.close()
        fle = open("login.txt","w")
        fle.writelines(list1)
        fle.close()
        
        fle2 = open("Add_Emp.txt","r")
        s = fle2.readlines()
        flagg = 0
        list2 = []
        for l in s:
            if emp_id not in l:
                list2.append(l)
            else:
                flagg = 1
        if flag == 0:
            print("No such employee found.")
        fle2.close()
        fle2 = open("Add_Emp.txt","w")
        fle2.writelines(list2)
        fle2.close()
        
    def add_HR(emp_id, hr_name, hr_dept, hr_role):
        file = open("Add_HR.txt","a")
        L = ["Employee_ID:",emp_id,"\t\tEmployee_Name:",hr_name, "\t\tEmployee_Department:",hr_dept,"\t\tEmployee_Role:",hr_role,"\n"]
        file.writelines(L)
        file.close()
        f = open("login.txt","a")
        q = emp_name.split()[0]
        LL = [emp_id,"\t",emp_name,"\n"]
        f.writelines(LL)
        f.close()
        
    def remove_hr(emp_id):
        fle = open("login.txt","r+")
        f = file.readlines()
        list1 = []
        flag = 0 
        for l in f:
            if emp_id not in l:
                list1.append(l)
            else:
                flag = 1
        if flag == 0:
            print("No such employee found.")
        fle.close()
        fle = open("login.txt","w")
        fle.writelines(list1)
        fle.close()
        
        fle2 = open("Add_HR.txt","r")
        s = fle2.readlines()
        flagg = 0
        list2 = []
        for l in s:
            if emp_id not in l:
                list2.append(l)
            else:
                flagg = 1
        if flag == 0:
            print("No such employee found.")
        fle2.close()
        fle2 = open("Add_HR.txt","w")
        fle2.writelines(list2)
        fle2.close()
    
    print("\n--------WELCOME TO ADMIN---------\n")
    choice = 0
    while(choice != 5):
        print("\n")
        print("ENTER 1 - TO ADD AN EMPLOYEE")
        print("ENTER 2 - TO REMOVE AN EMPLOYEE")
        print("ENTER 3 - TO ADD HR MEMBER")
        print("ENTER 4 - TO REMOVE HR MEMBER")
        print("ENTER 5 - TO EXIT THE ADMIN")
        choice = int(input())
        if choice == 1:
            emp_id = input("Enter the ID of employee:")
            emp_name = input("Enter the name of the employee:")
            emp_DOJ = input("Enter the Date of Joining of the employee:")
            emp_desig = input("Enter the designation of the employee:")
            emp_sal = "0" # salary was to be taken zero by default
            add_employee(emp_id, emp_name, emp_DOJ, emp_desig, emp_sal)
            
        elif choice == 2:
            emp_id = input("Enter the employee ID to remove: ")
            remove_emp(emp_id)
            
        elif choice == 3:
            emp_id = input("Enter the ID of employee:")
            hr_name = input("Enter the name of the employee:")
            hr_dept = input("Enter the Department of the employee:")
            hr_role = input("Enter the role of the employee:")
            add_HR(emp_id, hr_name, hr_dept, hr_role)
        
        elif choice == 4:
            emp_id = input("Enter the employee ID to remove: ")
            remove_hr(emp_id)

print("-------WELCOME TO EMPLOYEE SYSTEM--------\n")
login_id = input("Please Enter Login ID:")
password = input("Please Enter Passoword:")
file = open("login.txt","r")
x = file.readlines()
for i in x:
    if login_id + "\t" + password + "\n" in x:
        admin_module()   
    else:
        print("\nInvalid Login ID or Password!!!")
file.close()
# Out:
# -------WELCOME TO EMPLOYEE SYSTEM--------
#
# Please Enter Login ID:admin
# Please Enter Passoword:admin
#
# --------WELCOME TO ADMIN---------
#
#
#
# ENTER 1 - TO ADD AN EMPLOYEE
# ENTER 2 - TO REMOVE AN EMPLOYEE
# ENTER 3 - TO ADD HR MEMBER
# ENTER 4 - TO REMOVE HR MEMBER
# ENTER 5 - TO EXIT THE ADMIN
